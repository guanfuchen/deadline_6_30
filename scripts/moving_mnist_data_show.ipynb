# %%
import numpy as np
import os
import matplotlib.pyplot as plt

# %% [markdown]
# [conv_lstm.py](https://github.com/keras-team/keras/blob/master/examples/conv_lstm.py)

# %%
data_np = np.load(os.path.expanduser('~/Data/mnist_test_seq.npy'))

# %%
time_stamps, N, heigth, width = data_np.shape

# %%
for image_index in range(time_stamps):
    img = data_np[image_index, 0, :, :]
    plt.subplot(4, 5, image_index+1)
    plt.imshow(img, cmap='gray')
    plt.axis('off')
